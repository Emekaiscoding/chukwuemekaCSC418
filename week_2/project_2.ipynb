# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
password_dict = {
                "enase okonedo": { "name": "Enase Okonedo", "mat_no": 21124812734 ,"image": "enase-okonedo-vice-chancellor-pan-atlantic-university-268x300@2x.jpg"}, 
               "chris ogbechie": { "name": "Chris Ogbechie", "mat_no": 21120012834 ,"image": "Prof-Chris-Ogbechie-720x400-1-600x333.jpg"},
               "donatus ogbuike": { "name": "Donatus Ogbuike", "mat_no": 21120812444 ,"image": "pau-bursar.png"},
               "ikechukwu obiaya": { "name": "Ikechukwu Obiaya", "mat_no": 21120613334 ,"image": "Dr-obiaya-245x300@2x.jpg"},
}

# %%
your_username = input("Enter your name: ").lower()  # Convert to lowercase for consistency
your_matno= input("Enter your matno: ")
enhance_type = input("Enter a number to choose an enhancement type: \n1. Blur the image \n2. Scale the image \n3. Invert the image \n4. Overlap the image\n5. Brighten and increase contrast \n6. Sharpen Image\n")
enhance_type = int(enhance_type)


def blur_image():
    # Check if the name exists in the dictionary
    if your_username in password_dict:
        # Verify mat
        if password_dict[your_username]["mat_no"] == your_matno:
            image_path = f"./images/{password_dict[your_username]['image']}"  # Assuming images are in './images/' directory
            image = cv2.imread(image_path)
            
            if image is not None:  # Ensure image is loaded successfully
                window_name = password_dict[your_username]["name"].upper()  # Convert name to uppercase for display
                plt.subplot(1,2,1)
                plt.title("Original")
                plt.imshow(image)
                
                filtered_image = cv2.medianBlur(image, 15)
    
                cv2.imwrite("../images/blurred_image.png",filtered_image )
    
                plt.subplot(1,2,2)
                plt.title("Median Blur")
                plt.imshow(filtered_image)
                plt.show()
            else:
                print(f"Error: Image '{image_path}' not found!")
        else:
            print("Incorrect matno! Please try again.")
    else:
        print("Name not found in the system.")


if enhance_type == 1:
    blur_image()

if enhance_type == 2:
    scaled_image()
    
if enhance_type == 3:
    invert_image()
    
if enhance_type == 4:
    overlap_image()
    
if enhance_type == 5:
    bright_contrast()

if enhance_type == 6:
    sharpen_image()

# def scaled_image():

# def invert_image():

# def overlap_image():

# def bright_contrast():

# def sharpen_image():

    

# # Check if the name exists in the dictionary
# if your_name in password_dict:
#     # Verify mat
#     if password_dict[your_name]["password"] == your_password:
#         image_path = f"./images/{password_dict[your_name]['image']}"  # Assuming images are in './images/' directory
#         img = cv2.imread(image_path)
        
#         if img is not None:  # Ensure image is loaded successfully
#             img_resized = cv2.resize(img, (600, 400))  # Resize the image
#             window_name = password_dict[your_name]["name"].upper()  # Convert name to uppercase for display
            
#             cv2.imshow(window_name, img_resized)  
#             cv2.waitKey(0)
#             cv2.destroyAllWindows()
#         else:
#             print(f"Error: Image '{image_path}' not found!")
#     else:
#         print("Incorrect password! Please try again.")
# else:
#     print("Name not found in the system.")
# Out:
# Enter your name:  enase okonedo
# Enter your matno:  21124812734
# Enter a number to choose an enhancement type:
# 1. Blur the image
# 2. Scale the image
# 3. Invert the image
# 4. Overlap the image
# 5. Brighten and increase contrast
# 6. Sharpen Image
#  1
# Incorrect matno! Please try again.

# %%
print("Enter a number: \n1. Blur the image \n2. Scale the image \n3. Invert the image \n4. Overlapp the image\n5. Brighten and increase contrast \n6. Sharpen Image")
# Out:
# Enter a number:
# 1. Blur the image
# 2. Scale the image
# 3. Invert the image
# 4. Overlapp the image
# 5. Brighten and increase contrast
# 6. Sharpen Image

# %%
import cv2
import matplotlib.pyplot as plt

password_dict = {
                "enase okonedo": { "name": "Enase Okonedo", "mat_no": 21124812734 ,"image": "enase-okonedo-vice-chancellor-pan-atlantic-university-268x300@2x.jpg"}, 
               "chris ogbechie": { "name": "Chris Ogbechie", "mat_no": 21120012834 ,"image": "Prof-Chris-Ogbechie-720x400-1-600x333.jpg"},
               "donatus ogbuike": { "name": "Donatus Ogbuike", "mat_no": 21120812444 ,"image": "pau-bursar.png"},
               "ikechukwu obiaya": { "name": "Ikechukwu Obiaya", "mat_no": 21120613334 ,"image": "Dr-obiaya-245x300@2x.jpg"},
}

your_username = input("Enter your name: ").lower()
your_matno = input("Enter your matno: ")

try:
    enhance_type = int(input("Enter a number to choose an enhancement type: \n"
                             "1. Blur the image\n2. Scale the image\n"
                             "3. Invert the image\n4. Overlap the image\n"
                             "5. Brighten and increase contrast\n6. Sharpen Image\n"))
except ValueError:
    print("Invalid input! Please enter a number.")
    exit()


def blur_image():
    if your_username in password_dict:
        if password_dict[your_username]["mat_no"] == int(your_matno):
            image_path = f"../images/{password_dict[your_username]['image']}"
            image = cv2.imread(image_path)

            if image is not None:
                window_name = password_dict[your_username]["name"].upper()
                
                plt.subplot(1, 2, 1)
                plt.title("Original")
                plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                
                filtered_image = cv2.medianBlur(image, 15)
                cv2.imwrite("../images/blurred_image2.png", filtered_image)

                plt.subplot(1, 2, 2)
                plt.title("Median Blur")
                plt.imshow(cv2.cvtColor(filtered_image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                plt.show()
            else:
                print(f"Error: Image '{image_path}' not found!")
        else:
            print("Incorrect matno! Please try again.")
    else:
        print("Name not found in the system.")

# Define the missing functions
def scaled_image():
    if your_username in password_dict:
        if password_dict[your_username]["mat_no"] == int(your_matno):
            image_path = f"../images/{password_dict[your_username]['image']}"
            image = cv2.imread(image_path)

            if image is not None:
                window_name = password_dict[your_username]["name"].upper()
                
                plt.subplot(1, 2, 1)
                plt.title("Original")
                plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                
                scaled_image = cv2.resize(image, None, fx =2, fy = 3)
                cv2.imwrite("../images/scaled_image2.png", scaled_image)

                plt.subplot(1, 2, 2)
                plt.title("Scaled Image")
                plt.imshow(cv2.cvtColor(scaled_image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                plt.show()
            else:
                print(f"Error: Image '{image_path}' not found!")
        else:
            print("Incorrect matno! Please try again.")
    else:
        print("Name not found in the system.")

def invert_image():
    if your_username in password_dict:
        if password_dict[your_username]["mat_no"] == int(your_matno):
            image_path = f"../images/{password_dict[your_username]['image']}"
            image = cv2.imread(image_path)

            if image is not None:
                window_name = password_dict[your_username]["name"].upper()
                
                plt.subplot(1, 2, 1)
                plt.title("Original")
                plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                
                inverse_image = 255 - image
                cv2.imwrite("../images/inverted_image2.png", inverse_image)

                plt.subplot(1, 2, 2)
                plt.title("Inverted Image")
                plt.imshow(cv2.cvtColor(inverse_image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                plt.show()
            else:
                print(f"Error: Image '{image_path}' not found!")
        else:
            print("Incorrect matno! Please try again.")
    else:
        print("Name not found in the system.")

def overlap_image():
    if your_username in password_dict:
        if password_dict[your_username]["mat_no"] == int(your_matno):
            image_path = f"../images/{password_dict[your_username]['image']}"
            image = cv2.imread(image_path)

            if image is not None:
                window_name = password_dict[your_username]["name"].upper()
                
                plt.subplot(1, 2, 1)
                plt.title("Original")
                plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                
                inverse_image = 255 - image
                cv2.imwrite("../images/blurred_image.png", inverse_image)

                plt.subplot(1, 2, 2)
                plt.title("Median Blur")
                plt.imshow(cv2.cvtColor(inverse_image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                plt.show()
            else:
                print(f"Error: Image '{image_path}' not found!")
        else:
            print("Incorrect matno! Please try again.")
    else:
        print("Name not found in the system.")

def bright_contrast():
    if your_username in password_dict:
        if password_dict[your_username]["mat_no"] == int(your_matno):
            image_path = f"../images/{password_dict[your_username]['image']}"
            image = cv2.imread(image_path)

            if image is not None:
                window_name = password_dict[your_username]["name"].upper()
                
                plt.subplot(1, 2, 1)
                plt.title("Original")
                plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert to RGB
                
                brightness = 5
                contrast = 1.5
                image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape, image.dtype), 0, brightness)
                
                cv2.imwrite("../images/contrast_image2.png", image2)

                plt.subplot(1, 2, 2)
                plt.title("Bright Contrasted image")
                plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))  # Convert to RGB
                plt.show()
            else:
                print(f"Error: Image '{image_path}' not found!")
        else:
            print("Incorrect matno! Please try again.")
    else:
        print("Name not found in the system.")

def sharpen_image():
    print("Sharpening image...")

# Call the correct function based on user input
if enhance_type == 1:
    blur_image()
elif enhance_type == 2:
    scaled_image()
elif enhance_type == 3:
    invert_image()
elif enhance_type == 4:
    overlap_image()
elif enhance_type == 5:
    bright_contrast()
elif enhance_type == 6:
    sharpen_image()
else:
    print("Invalid selection!")
# Out:
# Enter your name:  enase okonedo
# Enter your matno:  21124812734
# Enter a number to choose an enhancement type:
# 1. Blur the image
# 2. Scale the image
# 3. Invert the image
# 4. Overlap the image
# 5. Brighten and increase contrast
# 6. Sharpen Image
#  5
