# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
users = {
    "emaka anyanwu": {"email": "chukwuemekaanyanwu322@gmail.com", "age": 18},
    "bona chukwu": {"email": "bonachukwu1@gmail.com", "age": 17},
    "tabitha udezi": {"email": "tabithaudezi23@gmail.com", "age": 23},
    "abdullah salami": {"email": "abdullahsalami343@gmail.com", "age": 26},
}

art_collections = {
    "cont_art": [
        "2019.0743.jpg", "2019.0715.jpg", "2019.0716.jpg", "2019.0187.jpg"
    ],
    "modern_art": [
        "2019.0728-ENWONWU-1.jpg", "2019.0262.-U.OKEKE.JPG-1.jpg", 
        "2019.0257-YUSUF-1.jpg", "2019.0256.AKOLO-1.jpg", "2019.0670.jpg", 
        "2019.0681.jpg", "2019.0312.WENGER-1.png", "2019.0707.jpg"
    ],
    "trad_art": [
        "2019.0119-UNKNOWN-1-1.jpg", "2019.0120-UNKNOWN-1.jpg", 
        "2019.0121-UNKNOWN-1.jpg", "2019.0124-UNKNOWN.jpg", 
        "2019.0133-UNKNOWN.jpg"
    ],
}

# %%
class Project:
    def __init__(self, username, email, age):
        self.username = username
        self.email = email
        self.age = age

    def login(self):
        if your_username in users :
            if users[your_username]["age"] > 18:
                image_path = f"./images/{password_dict[your_username]['image']}"
                 image = cv2.imread(image_path)
             else:
                print(f"Error: Image '{image_path}' not found!")
        else:
            print("Incorrect matno! Please try again.")
            
    def select_image(self):
        pass
    def select_transform_method(self):
        pass         

user_email = input("Enter your Email:" )

# %%
class Project:
    def __init__(self, username, email, age):
        self.username = username
        self.email = email
        self.age = age

    def login(self, users, password_dict, your_username):
        if your_username in users:
            if users[your_username]["age"] > 18:
                image_filename = password_dict[your_username]['image']
                image_path = f"./images/{image_filename}"
                
                image = cv2.imread(image_path)
                if image is None:
                    print(f"Error: Image '{image_filename}' not found!")
            else:
                print("User is under 18. Access restricted.")
        else:
            print("Incorrect username! Please try again.")

    def select_image(self):
        pass

    def select_transform_method(self):
        pass


your_username = input("Enter your username: ")
your_email = input("Enter your email: ")
your_age = int(input("Enter your age: "))

project = Project(username=your_username, email="example@example.com", age=users.get(your_username, {}).get("age", 0))
project.login(users, password_dict, your_username)

# %%
users = {
    "emaka anyanwu": {"email": "chukwuemekaanyanwu322@gmail.com", "age": 18},
    "bona chukwu": {"email": "bonachukwu1@gmail.com", "age": 17},
    "tabitha udezi": {"email": "tabithaudezi23@gmail.com", "age": 23},
    "abdullah salami": {"email": "abdullahsalami343@gmail.com", "age": 26},
}

art_collections = {
    "cont_art": [
        "2019.0743.jpg", "2019.0715.jpg", "2019.0716.jpg", "2019.0187.jpg"
    ],
    "modern_art": [
        "2019.0728-ENWONWU-1.jpg", "2019.0262.-U.OKEKE.JPG-1.jpg", 
        "2019.0257-YUSUF-1.jpg", "2019.0256.AKOLO-1.jpg", "2019.0670.jpg", 
        "2019.0681.jpg", "2019.0312.WENGER-1.png", "2019.0707.jpg"
    ],
    "trad_art": [
        "2019.0119-UNKNOWN-1-1.jpg", "2019.0120-UNKNOWN-1.jpg", 
        "2019.0121-UNKNOWN-1.jpg", "2019.0124-UNKNOWN.jpg", 
        "2019.0133-UNKNOWN.jpg"
    ],
}


import cv2  # Ensure OpenCV is installed

class Project:
    def __init__(self, username, email, age):
        self.username = username
        self.email = email
        self.age = age

    def login(self, users, password_dict, your_username):
        if your_username in users:
            if users[your_username]["age"] > 18:
                image_filename = password_dict[your_username]['image']
                image_path = f"./images/{image_filename}"
                
                image = cv2.imread(image_path)
                if image is None:
                    print(f"Error: Image '{image_filename}' not found!")
                else:
                    cv2.imshow("User Image", image)
                    cv2.waitKey(0)
                    cv2.destroyAllWindows()
            else:
                print("User is under 18. Access restricted.")
        else:
            print("Incorrect username! Please try again.")

    def display_images_in_category(self, category, art_collections):
        if category not in art_collections:
            print(f"Category '{category}' not found!")
            return

        images = art_collections[category]
        for image_filename in images:
            image_path = f"./images/{image_filename}"
            image = cv2.imread(image_path)

            if image is None:
                print(f"Error: Image '{image_filename}' not found!")
            else:
                print(f"Displaying: {image_filename}")
                cv2.imshow("Artwork", image)
                cv2.waitKey(0)  # Wait for user input before showing the next image
                cv2.destroyAllWindows()


# User input
your_username = input("Enter your username: ")
your_email = input("Enter your email: ")
your_age = int(input("Enter your age: "))

# Initialize Project
project = Project(username=your_username, email=your_email, age=your_age)
project.login(users, password_dict, your_username)

# Choose a category and display images
category = input("Enter an art category (cont_art, modern_art, trad_art): ").strip()
project.display_images_in_category(category, art_collections)
# Out:
# Enter your username:
# Enter your email:
# Enter your age:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 69
#      67 your_username = input("Enter your username: ")
#      68 your_email = input("Enter your email: ")
# ---> 69 your_age = int(input("Enter your age: "))
#      71 # Initialize Project
#      72 project = Project(username=your_username, email=your_email, age=your_age)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import cv2  # Ensure OpenCV is installed

# User Data
users = {
    "emaka anyanwu": {"email": "chukwuemekaanyanwu322@gmail.com", "age": 18},
    "bona chukwu": {"email": "bonachukwu1@gmail.com", "age": 17},
    "tabitha udezi": {"email": "tabithaudezi23@gmail.com", "age": 23},
    "abdullah salami": {"email": "abdullahsalami343@gmail.com", "age": 26},
}



# Art Collections
art_collections = {
    "cont_art": ["2019.0743.jpg", "2019.0715.jpg", "2019.0716.jpg", "2019.0187.jpg"],
    "modern_art": ["2019.0728-ENWONWU-1.jpg", "2019.0262.-U.OKEKE.JPG-1.jpg",
                   "2019.0257-YUSUF-1.jpg", "2019.0256.AKOLO-1.jpg", "2019.0670.jpg",
                   "2019.0681.jpg", "2019.0312.WENGER-1.png", "2019.0707.jpg"],
    "trad_art": ["2019.0119-UNKNOWN-1-1.jpg", "2019.0120-UNKNOWN-1.jpg",
                 "2019.0121-UNKNOWN-1.jpg", "2019.0124-UNKNOWN.jpg",
                 "2019.0133-UNKNOWN.jpg"]
}


class Project:
    def __init__(self, username, email, age):
        self.username = username
        self.email = email
        self.age = age

    def login(self, users, password_dict, username):
        username = username.lower()  # Normalize case for dictionary lookup

        if username not in users:
            print("User not found. Please check your username.")
            return

        user_age = users[username]["age"]

        if user_age > 18:
            image_filename = password_dict.get(username, {}).get("image")
            if not image_filename:
                print(f"No profile image found for {username}.")
                return

            image_path = f"./images/{image_filename}"
            image = cv2.imread(image_path)

            if image is None:
                print(f"Error: Profile image '{image_filename}' not found!")
            else:
                cv2.imshow("User Profile Image", image)
                cv2.waitKey(0)
                cv2.destroyAllWindows()
        else:
            print("User is under 18. Access restricted.")

    def display_images_in_category(self, category, art_collections):
        category = category.lower()  # Normalize input
        if category not in art_collections:
            print(f"Category '{category}' not found!")
            return

        images = art_collections[category]
        for image_filename in images:
            image_path = f"./images/{image_filename}"
            image = cv2.imread(image_path)

            if image is None:
                print(f"Error: Image '{image_filename}' not found!")
            else:
                print(f"Displaying: {image_filename}")
                cv2.imshow("Artwork", image)
                cv2.waitKey(0)  # Wait for user input before showing the next image
                cv2.destroyAllWindows()


# Get User Input
username_input = input("Enter your username: ").strip().lower()
email_input = input("Enter your email: ").strip()
age_input = users.get(username_input, {}).get("age", 0)

# Initialize Project and Login
project = Project(username=username_input, email=email_input, age=age_input)
project.login(users, password_dict, username_input)

# Display Art Collection
category_input = input("Enter an art category (cont_art, modern_art, trad_art): ").strip().lower()
project.display_images_in_category(category_input, art_collections)
# Out:
# Enter your username:
# Enter your email:
# User not found. Please check your username.
# Enter an art category (cont_art, modern_art, trad_art):
# Category '' not found!

# %%
import cv2
import numpy as np

# User Data
users = {
    "emeka anyanwu": {"email": "chukwuemekaanyanwu322@gmail.com", "age": 18},
    "bona chukwu": {"email": "bonachukwu1@gmail.com", "age": 17},
    "tabitha udezi": {"email": "tabithaudezi23@gmail.com", "age": 23},
    "abdullah salami": {"email": "abdullahsalami343@gmail.com", "age": 26},
}

# Art Collections
art_collections = {
    "cont_art": ["2019.0743.jpg", "2019.0715.jpg", "2019.0716.jpg", "2019.0187.jpg"],
    "modern_art": ["2019.0728-ENWONWU-1.jpg", "2019.0262.-U.OKEKE.JPG-1.jpg",
                   "2019.0257-YUSUF-1.jpg", "2019.0256.AKOLO-1.jpg", "2019.0670.jpg",
                   "2019.0681.jpg", "2019.0312.WENGER-1.png", "2019.0707.jpg"],
    "trad_art": ["2019.0119-UNKNOWN-1-1.jpg", "2019.0120-UNKNOWN-1.jpg",
                 "2019.0121-UNKNOWN-1.jpg", "2019.0124-UNKNOWN.jpg",
                 "2019.0133-UNKNOWN.jpg"]
}


class Project:
    def __init__(self, username, email):
        self.username = username.lower()
        self.email = email

    def verify_user(self, users):
        """Check if user exists and verify age."""
        if self.username in users and users[self.username]["email"] == self.email:
            user_age = users[self.username]["age"]
            if user_age >= 18:
                print(f"Welcome, {self.username.capitalize()}! You have access.")
                return True
            else:
                print("Access restricted. You must be at least 18.")
                return False
        print("User not found or incorrect email.")
        return False

    def display_images_in_category(self, category, art_collections):
        """Display images from the selected category."""
        category = category.lower()
        if category not in art_collections:
            print(f"Category '{category}' not found!")
            return

        images = art_collections[category]
        for image_filename in images:
            image_path = f"./images/{image_filename}"
            image = cv2.imread(image_path)

            if image is None:
                print(f"Error: Image '{image_filename}' not found!")
            else:
                print(f"Displaying: {image_filename}")
                cv2.imshow("Artwork", image)
                
                # Perform image transformation
                self.apply_transformations(image)
                
                cv2.waitKey(0)  # Wait for user input before showing the next image
                cv2.destroyAllWindows()

    def apply_transformations(self, image):
        """Apply transformations to the image."""
        print("\nChoose an image transformation:")
        print("1. Grayscale")
        print("2. Edge Detection (Canny)")
        print("3. Blurring")
        print("4. Rotate 90 degrees")
        print("5. Exit")

        while True:
            choice = input("Enter your choice (1-5): ").strip()
            if choice == "1":
                transformed_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                cv2.imshow("Grayscale Image", transformed_image)
            elif choice == "2":
                transformed_image = cv2.Canny(image, 100, 200)
                cv2.imshow("Edge Detection", transformed_image)
            elif choice == "3":
                transformed_image = cv2.GaussianBlur(image, (15, 15), 0)
                cv2.imshow("Blurred Image", transformed_image)
            elif choice == "4":
                transformed_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
                cv2.imshow("Rotated Image", transformed_image)
            elif choice == "5":
                print("Exiting transformations...")
                break
            else:
                print("Invalid choice. Try again.")

            cv2.waitKey(0)
            cv2.destroyAllWindows()


# Get user input
username_input = input("Enter your username: ").strip().lower()
email_input = input("Enter your email: ").strip()

# Initialize Project
project = Project(username=username_input, email=email_input)

# Verify user
if project.verify_user(users):
    category_input = input("Enter an art category (cont_art, modern_art, trad_art): ").strip().lower()
    project.display_images_in_category(category_input, art_collections)
# Out:
# Enter your username:  emeka anyanwu
# Enter your email:  chukwuemekaanyanwu322@gmail.com
# Welcome, Emeka anyanwu! You have access.
# Enter an art category (cont_art, modern_art, trad_art):  cont_art
# Error: Image '2019.0743.jpg' not found!
# Error: Image '2019.0715.jpg' not found!
# Error: Image '2019.0716.jpg' not found!
# Error: Image '2019.0187.jpg' not found!

# %%
import cv2
import os

# User Data
users = {
    "emeka anyanwu": {"email": "chukwuemekaanyanwu322@gmail.com", "age": 18},
    "bona chukwu": {"email": "bonachukwu1@gmail.com", "age": 17},
    "tabitha udezi": {"email": "tabithaudezi23@gmail.com", "age": 23},
    "abdullah salami": {"email": "abdullahsalami343@gmail.com", "age": 26},
}

# Define folders for each art collection
art_collections = {
    "cont_art": "./images/cont_art/",
    "modern_art": "./images/modern_art/",
    "trad_art": "./images/trad_art/"
}

class Project:
    def __init__(self, username, email):
        self.username = username.lower()
        self.email = email

    def verify_user(self, users):
        """Check if user exists and verify age."""
        if self.username in users and users[self.username]["email"] == self.email:
            user_age = users[self.username]["age"]
            if user_age >= 18:
                print(f"Welcome, {self.username.capitalize()}! You have access.")
                return True
            else:
                print("Access restricted. You must be at least 18.")
                return False
        print("User not found or incorrect email.")
        return False

    def display_images_in_category(self, category, art_collections):
        """Display images from the selected category's folder."""
        category = category.lower()
        if category not in art_collections:
            print(f"Category '{category}' not found!")
            return

        folder_path = art_collections[category]

        if not os.path.exists(folder_path):
            print(f"Error: Folder '{folder_path}' does not exist!")
            return

        images = [f for f in os.listdir(folder_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

        if not images:
            print(f"No images found in '{category}'.")
            return

        for image_filename in images:
            image_path = os.path.join(folder_path, image_filename)
            image = cv2.imread(image_path)

            if image is None:
                print(f"Error: Image '{image_filename}' not found or cannot be opened!")
            else:
                print(f"Displaying: {image_filename}")
                cv2.imshow("Artwork", image)

                # Perform image transformation
                self.apply_transformations(image)

                cv2.waitKey(0)  # Wait for user input before showing the next image
                cv2.destroyAllWindows()

    def apply_transformations(self, image):
        """Apply transformations to the image."""
        print("\nChoose an image transformation:")
        print("1. Grayscale")
        print("2. Edge Detection (Canny)")
        print("3. Blurring")
        print("4. Rotate 90 degrees")
        print("5. Exit")

        while True:
            choice = input("Enter your choice (1-5): ").strip()
            if choice == "1":
                transformed_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                cv2.imshow("Grayscale Image", transformed_image)
            elif choice == "2":
                transformed_image = cv2.Canny(image, 100, 200)
                cv2.imshow("Edge Detection", transformed_image)
            elif choice == "3":
                transformed_image = cv2.GaussianBlur(image, (15, 15), 0)
                cv2.imshow("Blurred Image", transformed_image)
            elif choice == "4":
                transformed_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
                cv2.imshow("Rotated Image", transformed_image)
            elif choice == "5":
                print("Exiting transformations...")
                break
            else:
                print("Invalid choice. Try again.")

            cv2.waitKey(0)
            cv2.destroyAllWindows()


# Get user input
username_input = input("Enter your username: ").strip().lower()
email_input = input("Enter your email: ").strip()

# Initialize Project
project = Project(username=username_input, email=email_input)

# Verify user
if project.verify_user(users):
    category_input = input("Enter an art category (cont_art, modern_art, trad_art): ").strip().lower()
    project.display_images_in_category(category_input, art_collections)
# Out:
# Enter your username:  emeka anyanwu
# Enter your email:  chukwuemekaanyanwu322@gmail.com
# Welcome, Emeka anyanwu! You have access.
# Enter an art category (cont_art, modern_art, trad_art):  cont_art
# Displaying: 2019.0187.jpg
#
# Choose an image transformation:
# 1. Grayscale
# 2. Edge Detection (Canny)
# 3. Blurring
# 4. Rotate 90 degrees
# 5. Exit
# Enter your choice (1-5):  1

# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np

# User Data
users = {
    "emeka anyanwu": {"email": "chukwuemekaanyanwu322@gmail.com", "age": 18},
    "bona chukwu": {"email": "bonachukwu1@gmail.com", "age": 17},
    "tabitha udezi": {"email": "tabithaudezi23@gmail.com", "age": 23},
    "abdullah salami": {"email": "abdullahsalami343@gmail.com", "age": 26},
}

# Define folders for each art collection
art_collections = {
    "cont_art": "./images/cont_art/",
    "modern_art": "./images/modern_art/",
    "trad_art": "./images/trad_art/"
}

class Project:
    def __init__(self, username, email):
        self.username = username.lower()
        self.email = email

    def verify_user(self, users):
        """Check if user exists and verify age."""
        if self.username in users and users[self.username]["email"] == self.email:
            user_age = users[self.username]["age"]
            if user_age >= 18:
                print(f"Welcome, {self.username.capitalize()}! You have access.")
                return True
            else:
                print("Access restricted. You must be at least 18.")
                return False
        print("User not found or incorrect email.")
        return False

    def display_images_in_category(self, category, art_collections):
        """Display images from the selected category's folder using Matplotlib."""
        category = category.lower()
        if category not in art_collections:
            print(f"Category '{category}' not found!")
            return

        folder_path = art_collections[category]

        if not os.path.exists(folder_path):
            print(f"Error: Folder '{folder_path}' does not exist!")
            return

        images = [f for f in os.listdir(folder_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

        if not images:
            print(f"No images found in '{category}'.")
            return

        print(f"\nDisplaying images from category: {category}")

        # Set up matplotlib figure
        fig, axes = plt.subplots(1, len(images), figsize=(5 * len(images), 5))

        if len(images) == 1:
            axes = [axes]  # Ensure axes is iterable for a single image

        for ax, image_filename in zip(axes, images):
            image_path = os.path.join(folder_path, image_filename)
            image = cv2.imread(image_path)
            if image is None:
                print(f"Error: Image '{image_filename}' not found or cannot be opened!")
                continue

            # Convert image from BGR to RGB for Matplotlib
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            ax.imshow(image_rgb)
            ax.set_title(image_filename)
            ax.axis("off")

        plt.show()

        # Ask user for transformations
        for image_filename in images:
            image_path = os.path.join(folder_path, image_filename)
            image = cv2.imread(image_path)
            if image is not None:
                self.apply_transformations(image, image_filename)

    def apply_transformations(self, image, image_name):
        """Apply transformations to the image and display with Matplotlib."""
        print(f"\nApplying transformations to: {image_name}")
        print("1. Grayscale")
        print("2. Edge Detection (Canny)")
        print("3. Blurring")
        print("4. Rotate 90 degrees")
        print("5. Exit")

        while True:
            choice = input("Enter your choice (1-5): ").strip()
            if choice == "1":
                img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
                
                plt.imshow(transformed_image, cmap="gray")
                plt.title(f"Grayscale - {image_name}")
            elif choice == "2":
                transformed_image = cv2.Canny(image, 100, 200)
                plt.imshow(transformed_image, cmap="gray")
                plt.title(f"Edge Detection - {image_name}")
            elif choice == "3":
                transformed_image = cv2.GaussianBlur(image, (15, 15), 0)
                plt.imshow(cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB))
                plt.title(f"Blurred - {image_name}")
            elif choice == "4":
                transformed_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
                plt.imshow(cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB))
                plt.title(f"Rotated 90° - {image_name}")
            elif choice == "5":
                print("Exiting transformations...\n")
                break
            else:
                print("Invalid choice. Try again.")
                continue

            plt.axis("off")
            plt.show()


# Get user input
username_input = input("Enter your username: ").strip().lower()
email_input = input("Enter your email: ").strip()

# Initialize Project
project = Project(username=username_input, email=email_input)

# Verify user
if project.verify_user(users):
    category_input = input("Enter an art category (cont_art, modern_art, trad_art): ").strip().lower()
    project.display_images_in_category(category_input, art_collections)
# Out:
# Enter your username:  emeka anyanwu
# Enter your email:  chukwuemekaanyanwu322@gmail.com
# Welcome, Emeka anyanwu! You have access.
# Enter an art category (cont_art, modern_art, trad_art):  cont_art
# Displaying images from category: cont_art
# Applying transformations to: 2019.0187.jpg
# 1. Grayscale
# 2. Edge Detection (Canny)
# 3. Blurring
# 4. Rotate 90 degrees
# 5. Exit
# Enter your choice (1-5):
# Invalid choice. Try again.
# Enter your choice (1-5):
# Invalid choice. Try again.
# Enter your choice (1-5):  1
# Enter your choice (1-5):  5
# Exiting transformations...
#
#
# Applying transformations to: 2019.0715.jpg
# 1. Grayscale
# 2. Edge Detection (Canny)
# 3. Blurring
# 4. Rotate 90 degrees
# 5. Exit
# Enter your choice (1-5):  i
# Invalid choice. Try again.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 136
#     134 if project.verify_user(users):
#     135     category_input = input("Enter an art category (cont_art, modern_art, trad_art): ").strip().lower()
# --> 136     project.display_images_in_category(category_input, art_collections)
#
# Cell In[3], line 86, in Project.display_images_in_category(self, category, art_collections)
#      84 image = cv2.imread(image_path)
#      85 if image is not None:
# ---> 86     self.apply_transformations(image, image_filename)
#
# Cell In[3], line 98, in Project.apply_transformations(self, image, image_name)
#      95 print("5. Exit")
#      97 while True:
# ---> 98     choice = input("Enter your choice (1-5): ").strip()
#      99     if choice == "1":
#     100         transformed_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import os
import matplotlib.pyplot as plt
import cv2

# User Data
users = {
    "emaka anyanwu": {"email": "chukwuemekaanyanwu322@gmail.com", "age": 18},
    "bona chukwu": {"email": "bonachukwu1@gmail.com", "age": 17},
    "tabitha udezi": {"email": "tabithaudezi23@gmail.com", "age": 23},
    "abdullah salami": {"email": "abdullahsalami343@gmail.com", "age": 26},
}

# Define folders for each art collection
art_collections = {
    "cont_art": "./images/cont_art/",
    "modern_art": "./images/modern_art/",
    "trad_art": "./images/trad_art/"
}

class Project:
    def __init__(self, username, email):
        self.username = username.lower()
        self.email = email

    def verify_user(self, users):
        """Check if user exists and verify age."""
        if self.username in users and users[self.username]["email"] == self.email:
            user_age = users[self.username]["age"]
            if user_age >= 18:
                print(f"Welcome, {self.username.capitalize()}! You have access.")
                return True
            else:
                print("Access restricted. You must be at least 18.")
                return False
        print("User not found or incorrect email.")
        return False

    def display_images_in_category(self, category, art_collections):
        """Display images from the selected category's folder using Matplotlib."""
        category = category.lower()
        if category not in art_collections:
            print(f"Category '{category}' not found!")
            return

        folder_path = art_collections[category]

        if not os.path.exists(folder_path):
            print(f"Error: Folder '{folder_path}' does not exist!")
            return

        images = [f for f in os.listdir(folder_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

        if not images:
            print(f"No images found in '{category}'.")
            return

        print(f"\nDisplaying images from category: {category}")

        # Set up matplotlib figure
        fig, axes = plt.subplots(1, len(images), figsize=(5 * len(images), 5))

        if len(images) == 1:
            axes = [axes]  # Ensure axes is iterable for a single image

        for ax, image_filename in zip(axes, images):
            image_path = os.path.join(folder_path, image_filename)
            image = cv2.imread(image_path)
            if image is None:
                print(f"Error: Image '{image_filename}' not found or cannot be opened!")
                continue

            # Convert image from BGR to RGB for Matplotlib
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            ax.imshow(image_rgb)
            ax.set_title(image_filename)
            ax.axis("off")

        plt.show()

        # Allow user to select an image to transform
        while True:
            print("\nType the name of the image you want to transform (or type 'exit' to quit).")
            selected_image = input("Enter image name: ").strip()

            if selected_image.lower() == 'exit':
                print("Exiting program...")
                return

            if selected_image not in images:
                print("Invalid image name. Try again.")
                continue

            # Load selected image for transformation
            image_path = os.path.join(folder_path, selected_image)
            image = cv2.imread(image_path)

            if image is not None:
                self.apply_transformations(image, selected_image)

    def apply_transformations(self, image, image_name):
        """Apply transformations to the selected image and display using Matplotlib."""
        print(f"\nApplying transformations to: {image_name}")
        print("1. Grayscale")
        print("2. Edge Detection (Canny)")
        print("3. Blurring")
        print("4. Rotate 90 degrees")
        print("5. Exit transformations")

        while True:
            choice = input("Enter your choice (1-5): ").strip()

            if choice == "1":
                transformed_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                plt.imshow(transformed_image, cmap="gray")
                plt.title(f"Grayscale - {image_name}")
            elif choice == "2":
                transformed_image = cv2.Canny(image, 100, 200)
                plt.imshow(transformed_image, cmap="gray")
                plt.title(f"Edge Detection - {image_name}")
            elif choice == "3":
                transformed_image = cv2.GaussianBlur(image, (15, 15), 0)
                plt.imshow(cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB))
                plt.title(f"Blurred - {image_name}")
            elif choice == "4":
                transformed_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
                plt.imshow(cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB))
                plt.title(f"Rotated 90° - {image_name}")
            elif choice == "5":
                print("Exiting transformations...\n")
                return
            else:
                print("Invalid choice. Try again.")
                continue

            plt.axis("off")
            plt.show()


# Get user input
username_input = input("Enter your username: ").strip().lower()
email_input = input("Enter your email: ").strip()

# Initialize Project
project = Project(username=username_input, email=email_input)

# Verify user
if project.verify_user(users):
    while True:
        category_input = input("Enter an art category (cont_art, modern_art, trad_art) or 'exit' to quit: ").strip().lower()
        
        if category_input == 'exit':
            print("Exiting program...")
            break
        
        project.display_images_in_category(category_input, art_collections)
# Out:
# Enter your username:  tabitha udezi
# Enter your email:  tabithaudezi23@gmail.com
# Welcome, Tabitha udezi! You have access.
# Enter an art category (cont_art, modern_art, trad_art) or 'exit' to quit:  cont_art
# Displaying images from category: cont_art
# Type the name of the image you want to transform (or type 'exit' to quit).
# Enter image name:  2019.0743.jpg
# Applying transformations to: 2019.0743.jpg
# 1. Grayscale
# 2. Edge Detection (Canny)
# 3. Blurring
# 4. Rotate 90 degrees
# 5. Exit transformations
# Enter your choice (1-5):  1
# Enter your choice (1-5):  exit
# Invalid choice. Try again.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 155
#     152     print("Exiting program...")
#     153     break
# --> 155 project.display_images_in_category(category_input, art_collections)
#
# Cell In[7], line 98, in Project.display_images_in_category(self, category, art_collections)
#      95 image = cv2.imread(image_path)
#      97 if image is not None:
# ---> 98     self.apply_transformations(image, selected_image)
#
# Cell In[7], line 110, in Project.apply_transformations(self, image, image_name)
#     107 print("5. Exit transformations")
#     109 while True:
# --> 110     choice = input("Enter your choice (1-5): ").strip()
#     112     if choice == "1":
#     113         transformed_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
